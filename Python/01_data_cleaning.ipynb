# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-73d278df-24cc-413d-95bf-e1e3732a2778" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-73d278df-24cc-413d-95bf-e1e3732a2778">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
sales = pd.read_csv('sales_data.csv')
sales.head()
# Out:
#    order_id  order_date store_id   region product_id product_name   category  \
# 0   1000000  2023-04-13      S29  Central        P04     iPad Air     Tablet
# 1   1000001  2024-09-06      S19    South        P02  Samsung S23      Phone
# 2   1000002  2023-03-29      S36     East        P05  Apple Watch  Accessory
# 3   1000003  2024-10-23      S02    North        P05  Apple Watch  Accessory
# 4   1000004  2024-01-21      S21  Central        P08    iPhone 13      Phone
#
#    quantity  unit_price   revenue
# 0         5    14610268  72783520
# 1         4    18454698  73954866
# 2         5     7778167  37931925
# 3         5     8218315  40418644
# 4        -2    16684779 -32973533

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   order_id      200000 non-null  int64
#  1   order_date    200000 non-null  object
#  2   store_id      200000 non-null  object
#  3   region        200000 non-null  object
#  4   product_id    200000 non-null  object
#  5   product_name  200000 non-null  object
#  6   category      200000 non-null  object
#  7   quantity      200000 non-null  int64
#  8   unit_price    200000 non-null  int64
#  9   revenue       200000 non-null  int64
# dtypes: int64(4), object(6)
# memory usage: 15.3+ MB

# %%
sales.describe()
# Out:
#            order_id       quantity    unit_price       revenue
# count  2.000000e+05  200000.000000  2.000000e+05  2.000000e+05
# mean   1.100000e+06       2.498285  1.219737e+07  3.043886e+07
# std    5.773517e+04       2.872634  5.612511e+06  4.099547e+07
# min    1.000000e+06      -2.000000  4.000091e+06 -4.194450e+07
# 25%    1.050000e+06       0.000000  7.500207e+06 -9.482250e+03
# 50%    1.100000e+06       3.000000  1.450846e+07  2.293229e+07
# 75%    1.149999e+06       5.000000  1.751109e+07  5.370267e+07
# max    1.199999e+06       7.000000  2.049997e+07  1.442462e+08

# %%
sales.isnull().sum()
# Out:
# order_id        0
# order_date      0
# store_id        0
# region          0
# product_id      0
# product_name    0
# category        0
# quantity        0
# unit_price      0
# revenue         0
# dtype: int64

# %%
sales['order_id'].duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 199995    False
# 199996    False
# 199997    False
# 199998    False
# 199999    False
# Name: order_id, Length: 200000, dtype: bool

# %%
sales[sales['quantity'] <= 0].shape
# Out:
# (59988, 10)

# %%
sales = sales[sales['quantity']> 0]

# %%
(sales['quantity'] <= 0).sum()
# Out:
# np.int64(0)

# %%
sales[sales['unit_price'] <= 0].shape
# Out:
# (0, 10)

# %%
(sales['unit_price'] <= 0).sum()
# Out:
# np.int64(0)

# %%
sales['new_revenue'] = sales['quantity'] * sales['unit_price']
sales.head()
# Out:
#    order_id  order_date store_id   region product_id product_name   category  \
# 0   1000000  2023-04-13      S29  Central        P04     iPad Air     Tablet
# 1   1000001  2024-09-06      S19    South        P02  Samsung S23      Phone
# 2   1000002  2023-03-29      S36     East        P05  Apple Watch  Accessory
# 3   1000003  2024-10-23      S02    North        P05  Apple Watch  Accessory
# 5   1000005  2023-01-22      S44     West        P05  Apple Watch  Accessory
#
#    quantity  unit_price  new_revenue
# 0         5    14610268     73051340
# 1         4    18454698     73818792
# 2         5     7778167     38890835
# 3         5     8218315     41091575
# 5         6     8417040     50502240

# %%
sales[['quantity','unit_price','new_revenue']].head()
# Out:
#    quantity  unit_price  new_revenue
# 0         5    14610268     73051340
# 1         4    18454698     73818792
# 2         5     7778167     38890835
# 3         5     8218315     41091575
# 5         6     8417040     50502240

# %%
sales = sales.drop(columns=['revenue'])

# %%
sales = sales.rename(columns={'new_revenue': 'revenue'})

# %%
sales['order_date'] = pd.to_datetime(sales['order_date'])

# %%
sales['year'] = sales['order_date'].dt.year
sales['month'] = sales['order_date'].dt.month

# %%
output_path = "/content/sales_data_clean.csv"
sales.to_csv(output_path, index=False)

# %%
from google.colab import files
files.download(output_path)
